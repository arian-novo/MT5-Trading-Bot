# %%
pip install MetaTrader5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: MetaTrader5 in c:\users\hp\appdata\roaming\python\python38\site-packages (5.0.4803)
# Requirement already satisfied: numpy>=1.7 in c:\users\hp\appdata\roaming\python\python38\site-packages (from MetaTrader5) (1.24.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import MetaTrader5 as mt
from datetime import datetime

# %%
mt.initialize()
# Out:
# True

# %%
login = 5033035641
password = 'Ro_3HuSz'
server = 'MetaQuotes-Demo'

# %%
mt.login(login,password,server)
# Out:
# True

# %%
rates = mt.copy_rates_from("EURUSD", mt.TIMEFRAME_H4,datetime.now(), 10)
rates
# Out:
# array([(1737504000, 1.04259, 1.04325, 1.03925, 1.04095,  5756, 3, 0),
#        (1737518400, 1.04092, 1.04212, 1.04061, 1.04155,  4342, 0, 0),
#        (1737532800, 1.04155, 1.04472, 1.03999, 1.04463,  9432, 0, 0),
#        (1737547200, 1.04466, 1.04572, 1.04222, 1.04316,  8936, 3, 0),
#        (1737561600, 1.04312, 1.04317, 1.04119, 1.04169, 10010, 3, 0),
#        (1737576000, 1.0417 , 1.04228, 1.04053, 1.04053,  4645, 0, 0),
#        (1737590400, 1.04053, 1.04158, 1.04019, 1.04036,  3878, 0, 0),
#        (1737604800, 1.04035, 1.04127, 1.03969, 1.04052,  4342, 0, 0),
#        (1737619200, 1.04053, 1.04147, 1.03899, 1.04116,  7717, 3, 0),
#        (1737633600, 1.04117, 1.04203, 1.0394 , 1.04105,  8487, 4, 0)],
#       dtype=[('time', '<i8'), ('open', '<f8'), ('high', '<f8'), ('low', '<f8'), ('close', '<f8'), ('tick_volume', '<u8'), ('spread', '<i4'), ('real_volume', '<u8')])

# %%
ticker = 'EURUSD'
interval = mt.TIMEFRAME_M1
from_date = datetime.now()
no_of_rows = 100
qty=0.01

rates = mt.copy_rates_from(ticker, interval, from_date, no_of_rows)
rates
# Out:
# array([(1737641400, 1.03981, 1.03983, 1.03972, 1.03972, 30, 4, 0),
#        (1737641460, 1.03973, 1.03977, 1.03972, 1.03972, 31, 4, 0),
#        (1737641520, 1.03972, 1.03972, 1.0395 , 1.03954, 41, 4, 0),
#        (1737641580, 1.03954, 1.03954, 1.0394 , 1.03943, 48, 4, 0),
#        (1737641640, 1.03942, 1.0397 , 1.0394 , 1.03969, 41, 4, 0),
#        (1737641700, 1.0397 , 1.03984, 1.03969, 1.03972, 34, 4, 0),
#        (1737641760, 1.03973, 1.03982, 1.03967, 1.03981, 42, 4, 0),
#        (1737641820, 1.03981, 1.03982, 1.0397 , 1.03977, 36, 4, 0),
#        (1737641880, 1.03977, 1.03984, 1.0397 , 1.0397 , 30, 4, 0),
#        (1737641940, 1.0397 , 1.03976, 1.0397 , 1.03973, 39, 4, 0),
#        (1737642000, 1.03972, 1.03972, 1.03951, 1.03967, 38, 4, 0),
#        (1737642060, 1.03964, 1.03973, 1.03962, 1.03967, 46, 4, 0),
#        (1737642120, 1.03964, 1.0397 , 1.03964, 1.03966, 30, 4, 0),
#        (1737642180, 1.03965, 1.03967, 1.03958, 1.03959, 20, 4, 0),
#        (1737642240, 1.03959, 1.03986, 1.03959, 1.03978, 39, 4, 0),
#        (1737646740, 1.04129, 1.04129, 1.04107, 1.04124, 63, 4, 0),
#        (1737646800, 1.04124, 1.04131, 1.041  , 1.04128, 65, 4, 0),
#        (1737646860, 1.04128, 1.04128, 1.04096, 1.04102, 55, 4, 0),
#        (1737646920, 1.04102, 1.0412 , 1.04097, 1.04102, 47, 4, 0),
#        (1737646980, 1.04102, 1.04115, 1.04093, 1.04101, 53, 4, 0),
#        (1737647040, 1.04099, 1.0411 , 1.04087, 1.04087, 63, 4, 0),
#        (1737647100, 1.04087, 1.04098, 1.04058, 1.04059, 52, 4, 0),
#        (1737647160, 1.04059, 1.04072, 1.04047, 1.04061, 41, 4, 0),
#        (1737647220, 1.04068, 1.04083, 1.04049, 1.04074, 45, 4, 0),
#        (1737647280, 1.04075, 1.04083, 1.04062, 1.04072, 52, 4, 0),
#        (1737647340, 1.04072, 1.04078, 1.04044, 1.04075, 54, 4, 0)],
#       dtype=[('time', '<i8'), ('open', '<f8'), ('high', '<f8'), ('low', '<f8'), ('close', '<f8'), ('tick_volume', '<u8'), ('spread', '<i4'), ('real_volume', '<u8')])

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\hp\appdata\roaming\python\python38\site-packages (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\roaming\python\python38\site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python38\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\roaming\python\python38\site-packages (from pandas) (2025.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\hp\appdata\roaming\python\python38\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
ohlc = pd.DataFrame(mt.copy_rates_range(ticker, interval, datetime(2025,1,20), datetime.now()))
ohlc['time']=pd.to_datetime(ohlc['time'],unit='s')
ohlc
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-20 00:01:00  1.02731  1.02753  1.02687  1.02753            5
# 1    2025-01-20 00:02:00  1.02754  1.02764  1.02754  1.02764            3
# 2    2025-01-20 00:03:00  1.02740  1.02764  1.02740  1.02764            2
# 3    2025-01-20 00:04:00  1.02740  1.02743  1.02740  1.02743            2
# 4    2025-01-20 00:05:00  1.02764  1.02765  1.02761  1.02765            8
# ...                  ...      ...      ...      ...      ...          ...
# 5264 2025-01-23 15:45:00  1.04087  1.04098  1.04058  1.04059           52
# 5265 2025-01-23 15:46:00  1.04059  1.04072  1.04047  1.04061           41
# 5266 2025-01-23 15:47:00  1.04068  1.04083  1.04049  1.04074           45
# 5267 2025-01-23 15:48:00  1.04075  1.04083  1.04062  1.04072           52
# 5268 2025-01-23 15:49:00  1.04072  1.04078  1.04044  1.04075           54
#
#       spread  real_volume
# 0         57            0
# 1        136            0
# 2        136            0
# 3        150            0
# 4        126            0
# ...      ...          ...
# 5264       4            0
# 5265       4            0
# 5266       4            0
# 5267       4            0
# 5268       4            0
#
# [5269 rows x 8 columns]

# %%
request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": ticker,
    "volume": qty,
    "type": mt.ORDER_TYPE_BUY,
    "price": mt.symbol_info_tick(ticker).ask,
    "sl": 0.041,
    "tp": 1.2,
    "comment": "python script open",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_FOK,
}

result = mt.order_send(request)
result
# Out:
# OrderSendResult(retcode=10009, deal=52000669006, order=52045010189, volume=0.01, price=1.03919, bid=1.03914, ask=1.03919, comment='Request executed', request_id=3817642717, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='EURUSD', volume=0.01, price=1.03919, stoplimit=0.0, sl=0.041, tp=1.2, deviation=0, type=0, type_filling=0, type_time=0, expiration=0, comment='python script open', position=0, position_by=0))

# %%
request = {
    "action": mt.TRADE_ACTION_DEAL,
    "symbol": ticker,
    "volume": qty,
    "type": mt.ORDER_TYPE_SELL,
    "position": mt.positions_get()[0]._asdict()['ticket'],
    "price": mt.symbol_info_tick(ticker).bid,
    "comment": "Close Position",
    "type_time": mt.ORDER_TIME_GTC,
    "type_filling": mt.ORDER_FILLING_FOK,
}

order = mt.order_send(request)
print(order)
# Out:
# OrderSendResult(retcode=10009, deal=52000669019, order=52045010202, volume=0.01, price=1.03914, bid=1.03914, ask=1.03919, comment='Request executed', request_id=3817642718, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='EURUSD', volume=0.01, price=1.03914, stoplimit=0.0, sl=0.0, tp=0.0, deviation=0, type=1, type_filling=0, type_time=0, expiration=0, comment='Close Position', position=52044703119, position_by=0))

# %%
mt.positions_get()[0]._asdict()['ticket']
# Out:
# 52044739925

# %%
ticker = 'EURUSD'
qty = 10.0
buy_order_type = mt.ORDER_TYPE_BUY
sell_order_type = mt.ORDER_TYPE_SELL
buy_price = mt.symbol_info_tick('EURUSD').ask
sell_price = mt.symbol_info_tick('EURUSD').bid
sl_pct = 0.05
tp_pct = 0.952
buy_sl = buy_price * (1-sl_pct)
buy_tp = buy_price * (1+tp_pct)
sell_sl = sell_price * (1+sl_pct)
sell_tp = sell_price * (1-tp_pct)


def create_order(ticker, qty, order_type, price, sl, tp):
    request = {
        "action": mt.TRADE_ACTION_DEAL,
        "symbol": ticker,
        "volume": qty,
        "type": order_type,
        "price": price,
        "sl": sl,
        "tp": tp,
        "comment": "python open",
        "type_time": mt.ORDER_TIME_GTC,
        "type_filling": mt.ORDER_FILLING_FOK,
    }
    order = mt.order_send(request)
    return order

def close_order(ticker, qty, order_type, price):
    request = {
        "action": mt.TRADE_ACTION_DEAL,
        "symbol": ticker,
        "volume": qty,
        "type": order_type,
        "position": mt.positions_get()[0]._asdict()['ticket'],
        "price": price,
        "comment": "Close Position",
        "type_time": mt.ORDER_TIME_GTC,
        "type_filling": mt.ORDER_FILLING_FOK,
    }
    order = mt.order_send(request)
    return order

# %%
create_order(ticker, qty, buy_order_type, buy_price, buy_sl, buy_tp)
# Out:
# OrderSendResult(retcode=10019, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='No money', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='EURUSD', volume=10.0, price=1.03919, stoplimit=0.0, sl=0.9872305, tp=2.02849888, deviation=0, type=0, type_filling=0, type_time=0, expiration=0, comment='python open', position=0, position_by=0))

# %%
close_order(ticker, qty, buy_order_type, buy_price)
# Out:
# OrderSendResult(retcode=10013, deal=0, order=0, volume=0.0, price=0.0, bid=0.0, ask=0.0, comment='Invalid request', request_id=0, retcode_external=0, request=TradeRequest(action=1, magic=0, order=0, symbol='EURUSD', volume=10.0, price=1.03919, stoplimit=0.0, sl=0.0, tp=0.0, deviation=0, type=0, type_filling=0, type_time=0, expiration=0, comment='Close Position', position=52044739925, position_by=0))

# %%
import time

for i in range(100000000000000):
    ohlc = pd.DataFrame(mt.copy_rates_range(ticker, interval, datetime(2025,1,23), datetime.now()))
    ohlc['time']=pd.to_datetime(ohlc['time'],unit='s')
    print(ohlc)

    current_close = list(ohlc[-1:]['close'])[0]
    last_close = list(ohlc[-2:]['close'])[0]
    last_high = list(ohlc[-2:]['high'])[0]
    last_low = list(ohlc[-2:]['low'])[0]
    long_condition = current_close > last_high
    short_condition = current_close < last_low
    closelong_condition = current_close < last_close
    closeshort_condition = current_close > last_close

    already_buy = False
    already_sell = False

    try:
        already_sell = mt.positions_get()[0]._asdict()['type'] == 1
        already_buy = mt.positions_get()[0]._asdict()['type'] == 0
    except:
        pass

    no_positions = len(mt.positions_get()) == 0

    if long_condition:
        if no_positions:
            create_order(ticker, qty, buy_order_type, buy_price, buy_sl, buy_tp)
            print('Buy Order Placed')
        if already_sell:
            close_order(ticker, qty, buy_order_type, buy_price)
            print('Sell Position Closed')
            time.sleep(1)
            create_order(ticker, qty, buy_order_type, buy_price, buy_sl, buy_tp)
            print('Buy Order Placed')
    if short_condition:
        if no_positions:
            create_order(ticker, qty, sellorder_type, sell_price, sell_sl, sell_tp)
            print('Sell Order Placed')
        if already_buy:
            close_order(ticker, qty, sell_order_type, sell_price)
            print('Buy Position Closed')
            time.sleep(1)
            create_order(ticker, qty, sell_order_type, sell_price, sell_sl, sell_tp)
            print('Buy Order Placed')

    try:
         already_sell = mt.positions_get()[0]._asdict()['type'] == 1
         already_buy = mt.positions_get()[0]._asdict()['type'] == 0
    except:
         pass


    if closelong_condition and already_buy:
         close_order(ticker,qty,sell_order_type,sell_price)
         print('Only Buy Position Closed')
    if closeshort_condition and already_sell:
         close_order(ticker,qty,buy_order_type,buy_price)
         print('Only Sell Position Closed')

    already_buy = False
    already_sell = False
    time.sleep(60)
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2025-01-22 18:00:00  1.04198  1.04198  1.04182  1.04186           53
# 1    2025-01-22 18:01:00  1.04187  1.04197  1.04170  1.04173           60
# 2    2025-01-22 18:02:00  1.04175  1.04192  1.04167  1.04181           57
# 3    2025-01-22 18:03:00  1.04181  1.04182  1.04168  1.04179           48
# 4    2025-01-22 18:04:00  1.04180  1.04191  1.04161  1.04191           55
# ...                  ...      ...      ...      ...      ...          ...
# 1305 2025-01-23 15:45:00  1.04087  1.04098  1.04058  1.04059           52
# 1306 2025-01-23 15:46:00  1.04059  1.04072  1.04047  1.04061           41
# 1307 2025-01-23 15:47:00  1.04068  1.04083  1.04049  1.04074           45
# 1308 2025-01-23 15:48:00  1.04075  1.04083  1.04062  1.04072           52
# 1309 2025-01-23 15:49:00  1.04072  1.04078  1.04044  1.04075           54
#
#       spread  real_volume
# 0          4            0
# 1          4            0
# 2          4            0
# 3          4            0
# 4          4            0
# ...      ...          ...
# 1305       4            0
# 1306       4            0
# 1307       4            0
# 1308       4            0
# 1309       4            0
#
# [1310 rows x 8 columns]
